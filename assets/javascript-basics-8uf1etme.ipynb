# %% [markdown]
# # JavaScript kernel
#
# Run code cells with the **JavaScript** kernel. Each cell runs in a shared runtime.

# %%
const x = 1 + 2;
return x;

# %%
const items = ['DuckDB', 'PGlite', 'Notebooks'];
return items.join(', ');

# %%
const fib = (n) => n <= 1 ? n : fib(n - 1) + fib(n - 2);
return fib(10);
